# %%
import pandas as pd

df = pd.read_csv("../data/sample.csv")
print("Shape:", df.shape)
print(df.head())
print(df.describe())
# Out:
# Shape: (5, 3)
#   coffee_name  size_ml  price_jod
# 0    Espresso       30       1.00
# 1  Cappuccino      250       2.50
# 2       Latte      300       2.75
# 3       Mocha      320       3.00
# 4   Cold Brew      350       3.25
#           size_ml  price_jod
# count    5.000000   5.000000
# mean   250.000000   2.500000
# std    128.257553   0.883883
# min     30.000000   1.000000
# 25%    250.000000   2.500000
# 50%    300.000000   2.750000
# 75%    320.000000   3.000000
# max    350.000000   3.250000
